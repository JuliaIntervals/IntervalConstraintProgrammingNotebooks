# %% [markdown]
# # Action of a separator

# %% [markdown]
# This notebook shows the action of a separator corresponding to a given set.

# %%
using ValidatedNumerics, IntervalConstraintProgramming, Plots, Interact
gr();  # GR backend
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	case "text/latex":
# 		if (MathJax){
# 			var math = MathJax.Hub.getAllJax(container)[0];
# 			MathJax.Hub.Queue(["Text", math, val.replace(/^\${1,2}|\${1,2}$/g, '')]);
# 			break;
# 		}
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (typeof(val[type]) !== "undefined" && val[type] !== null) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>
# Plots.GRBackend()

# %%
C = @constraint 4 <= x^2 + y^2 <= 9
# Out:
# Separator:
# - variables: x, y
# - expression: x ^ 2 + y ^ 2 ∈ [4, 9]

# %%
x = y = -∞..∞
X = x × y
# Out:
# [-∞, ∞] × [-∞, ∞]

# %%
paving = pave(C, X, 0.02)
# Out:
# Paving:
# - tolerance ϵ = 0.02
# - inner approx. of length 2568
# - boundary approx. of length 2568

# %%
plot(paving.inner, aspect_ratio=:equal, lw=0, label="full")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 118.381,384.952 499.397,384.952 499.397,3.93701 118.381,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="118" y="3" width="382" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   181.883,379.237 181.883,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   245.386,379.237 245.386,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   308.889,379.237 308.889,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   372.392,379.237 372.392,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   435.895,379.237 435.895,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   124.096,321.45 493.681,321.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   124.096,257.947 493.681,257.947
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   124.096,194.444 493.681,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   124.096,130.941 493.681,130.941
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   124.096,67.4385 493.681,67.4385
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   118.381,384.952 499.397,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   181.883,384.952 181.883,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   245.386,384.952 245.386,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   308.889,384.952 308.889,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   372.392,384.952 372.392,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   435.895,384.952 435.895,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   118.381,384.952 118.381,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   118.381,321.45 124.096,321.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   118.381,257.947 124.096,257.947
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   118.381,194.444 124.096,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   118.381,130.941 124.096,130.941
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   118.381,67.4385 124.096,67.4385
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 181.883, 396.952)" x="181.883" y="396.952">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 245.386, 396.952)" x="245.386" y="396.952">-1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 308.889, 396.952)" x="308.889" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 372.392, 396.952)" x="372.392" y="396.952">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 435.895, 396.952)" x="435.895" y="396.952">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 117.181, 325.95)" x="117.181" y="325.95">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 117.181, 262.447)" x="117.181" y="262.447">-1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 117.181, 198.944)" x="117.181" y="198.944">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 117.181, 135.441)" x="117.181" y="135.441">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 117.181, 71.9385)" x="117.181" y="71.9385">2</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 443.005,60.8121 443.842,60.8121 443.842,59.9776 443.005,59.9776 443.005,60.8121
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   443.005,60.8121 443.842,60.8121 443.842,59.9776 443.005,59.9776 443.005,60.8121
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 441.342,60.8121 443.005,60.8121 443.005,59.143 441.342,59.143 441.342,60.8121
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   441.342,60.8121 443.005,60.8121 443.005,59.143 441.342,59.143 441.342,60.8121
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 441.342,59.143 442.173,59.143 442.173,58.3237 441.342,58.3237 441.342,59.143
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   441.342,59.143 442.173,59.143 442.173,58.3237 441.342,58.3237 441.342,59.143
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 441.342,64.1098 444.668,64.1098 444.668,60.8121 441.342,60.8121 441.342,64.109

# %% [markdown]
# We choose two boxes that we wish to contract:

# %%
Y1 = (2.3..4) × (-1..0.5)
Y2 = (-3.5.. -1) × (-1.5..0)

plot(paving.inner, aspect_ratio=:equal, lw=0, label="full")
plot!(Y1, label="Y1")
plot!(Y2, label="Y2")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 70.7528,384.952 547.025,384.952 547.025,3.93701 70.7528,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="70" y="3" width="477" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   166.007,379.237 166.007,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   293.013,379.237 293.013,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   420.019,379.237 420.019,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   547.025,379.237 547.025,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,321.45 539.881,321.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,257.947 539.881,257.947
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,194.444 539.881,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,130.941 539.881,130.941
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,67.4385 539.881,67.4385
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,384.952 547.025,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   166.007,384.952 166.007,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   293.013,384.952 293.013,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   420.019,384.952 420.019,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   547.025,384.952 547.025,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,384.952 70.7528,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,321.45 77.8969,321.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,257.947 77.8969,257.947
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,194.444 77.8969,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,130.941 77.8969,130.941
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,67.4385 77.8969,67.4385
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 166.007, 396.952)" x="166.007" y="396.952">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 293.013, 396.952)" x="293.013" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 420.019, 396.952)" x="420.019" y="396.952">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 547.025, 396.952)" x="547.025" y="396.952">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 325.95)" x="69.5528" y="325.95">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 262.447)" x="69.5528" y="262.447">-1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 198.944)" x="69.5528" y="198.944">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 135.441)" x="69.5528" y="135.441">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 71.9385)" x="69.5528" y="71.9385">2</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 427.129,60.8121 427.966,60.8121 427.966,59.9776 427.129,59.9776 427.129,60.8121
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   427.129,60.8121 427.966,60.8121 427.966,59.9776 427.129,59.9776 427.129,60.8121
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 425.466,60.8121 427.129,60.8121 427.129,59.143 425.466,59.143 425.466,60.8121
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   425.466,60.8121 427.129,60.8121 427.129,59.143 425.466,59.143 425.466,60.8121
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 425.466,59.143 426.298,59.143 426.298,58.3237 425.466,58.3237 425.466,59.143
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   425.466,59.143 426.298,59.143 426.298,58.3237 425.466,58.3237 425.466,59.143
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 425.466,64.1098 428.793,64.1098 428.793,60.8121 425.466,60.8121 425.466,64.1098
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   425.466,64.1098 428.793,64.1098 428.793,60.8121 425.466,60.8121 425.466,64.1098
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 428.793,62.461 429.599,62.461 429.599,61.6366 428.793,61.6366 428.793,62.461
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   428.793,62.461 429.599,62.461 429.599,61.6366 428.793,6

# %%
plot(paving.inner, aspect_ratio=:equal, lw=0, label="", alpha=1)

inner1, outer1 = map(IntervalBox, C(Y1))

plot!(inner1, label="inner1", alpha=0.01)
plot!(outer1, label="outer1", alpha=0.01)


inner2, outer2 = map(IntervalBox, C(Y2))

plot!(inner2, label="inner2", alpha=0.01)
plot!(outer2, label="outer2", alpha=0.01)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 70.7528,384.952 547.025,384.952 547.025,3.93701 70.7528,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="70" y="3" width="477" height="382"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   166.007,379.237 166.007,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   293.013,379.237 293.013,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   420.019,379.237 420.019,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   547.025,379.237 547.025,9.65223
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,321.45 539.881,321.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,257.947 539.881,257.947
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,194.444 539.881,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,130.941 539.881,130.941
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   77.8969,67.4385 539.881,67.4385
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,384.952 547.025,384.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   166.007,384.952 166.007,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   293.013,384.952 293.013,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   420.019,384.952 420.019,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   547.025,384.952 547.025,379.237
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,384.952 70.7528,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,321.45 77.8969,321.45
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,257.947 77.8969,257.947
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,194.444 77.8969,194.444
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,130.941 77.8969,130.941
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   70.7528,67.4385 77.8969,67.4385
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 166.007, 396.952)" x="166.007" y="396.952">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 293.013, 396.952)" x="293.013" y="396.952">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 420.019, 396.952)" x="420.019" y="396.952">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 547.025, 396.952)" x="547.025" y="396.952">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 325.95)" x="69.5528" y="325.95">-2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 262.447)" x="69.5528" y="262.447">-1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 198.944)" x="69.5528" y="198.944">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 135.441)" x="69.5528" y="135.441">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 69.5528, 71.9385)" x="69.5528" y="71.9385">2</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 427.129,60.8121 427.966,60.8121 427.966,59.9776 427.129,59.9776 427.129,60.8121
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   427.129,60.8121 427.966,60.8121 427.966,59.9776 427.129,59.9776 427.129,60.8121
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 425.466,60.8121 427.129,60.8121 427.129,59.143 425.466,59.143 425.466,60.8121
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   425.466,60.8121 427.129,60.8121 427.129,59.143 425.466,59.143 425.466,60.8121
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 425.466,59.143 426.298,59.143 426.298,58.3237 425.466,58.3237 425.466,59.143
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   425.466,59.143 426.298,59.143 426.298,58.3237 425.466,58.3237 425.466,59.143
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 425.466,64.1098 428.793,64.1098 428.793,60.8121 425.466,60.8121 425.466,64.1098
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   425.466,64.1098 428.793,64.1098 428.793,60.8121 425.466,60.8121 425.466,64.1098
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 428.793,62.461 429.599,62.461 429.599,61.6366 428.793,61.6366 428.793,62.461
#   " fill="#0099ff" fill-opacity="0.5"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0; stroke-opacity:0.5; fill:none" points="
#   428.793,62.461 429.599,62.461 429.599,61.6366 428.793,6

# %% [markdown]
# Boxes that lie entirely inside the constraint set are not contracted by the inner contractor:

# %%
X = (-0.1.. 0.1) × (-2.5.. -2.3)
C(X)
# Out:
# ([-0.100001, 0.100001] × [-2.5, -2.29999],∅ × ∅)

# %% [markdown]
# Boxes that do not intersect the constraint set get contracted to the empty set by the inner contractor:

# %%
X = (4..5) × (-3.. -2)
C(X)
# Out:
# (∅ × ∅,[4, 5] × [-3, -2])
